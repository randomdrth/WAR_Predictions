# %%
# !pip install pybaseball
# Out:
# Collecting pybaseball
#   Downloading pybaseball-2.2.7-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.13.0 in /opt/anaconda3/lib/python3.12/site-packages (from pybaseball) (1.26.4)
# Requirement already satisfied: pandas>=1.0.3 in /opt/anaconda3/lib/python3.12/site-packages (from pybaseball) (2.2.2)
# Requirement already satisfied: beautifulsoup4>=4.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pybaseball) (4.12.3)
# Requirement already satisfied: requests>=2.18.1 in /opt/anaconda3/lib/python3.12/site-packages (from pybaseball) (2.32.3)
# Requirement already satisfied: lxml>=4.2.1 in /opt/anaconda3/lib/python3.12/site-packages (from pybaseball) (5.2.1)
# Requirement already satisfied: pyarrow>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from pybaseball) (16.1.0)
# Collecting pygithub>=1.51 (from pybaseball)
#   Downloading PyGithub-2.5.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: scipy>=1.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pybaseball) (1.13.1)
# Requirement already satisfied: matplotlib>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from pybaseball) (3.9.2)
# Requirement already satisfied: tqdm>=4.50.0 in /opt/anaconda3/lib/python3.12/site-packages (from pybaseball) (4.66.5)
# Requirement already satisfied: attrs>=20.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from pybaseball) (23.1.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.12/site-packages (from beautifulsoup4>=4.4.0->pybaseball) (2.5)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=2.0.0->pybaseball) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=2.0.0->pybaseball) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=2.0.0->pybaseball) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=2.0.0->pybaseball) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=2.0.0->pybaseball) (24.1)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=2.0.0->pybaseball) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=2.0.0->pybaseball) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=2.0.0->pybaseball) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.0.3->pybaseball) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.0.3->pybaseball) (2023.3)
# Collecting pynacl>=1.4.0 (from pygithub>=1.51->pybaseball)
#   Downloading PyNaCl-1.5.0-cp36-abi3-macosx_10_10_universal2.whl.metadata (8.7 kB)
# Requirement already satisfied: pyjwt>=2.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyjwt[crypto]>=2.4.0->pygithub>=1.51->pybaseball) (2.8.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from pygithub>=1.51->pybaseball) (4.11.0)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/anaconda3/lib/python3.12/site-packages (from pygithub>=1.51->pybaseball) (2.2.3)
# Collecting Deprecated (from pygithub>=1.51->pybaseball)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.18.1->pybaseball) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.18.1->pybaseball) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.18.1->pybaseball) (2024.8.30)
# Requirement already satisfied: cryptography>=3.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyjwt[crypto]>=2.4.0->pygithub>=1.51->pybaseball) (43.0.0)
# Requirement already satisfied: cffi>=1.4.1 in /opt/anaconda3/lib/python3.12/site-packages (from pynacl>=1.4.0->pygithub>=1.51->pybaseball) (1.17.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->pybaseball) (1.16.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/anaconda3/lib/python3.12/site-packages (from Deprecated->pygithub>=1.51->pybaseball) (1.14.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.12/site-packages (from cffi>=1.4.1->pynacl>=1.4.0->pygithub>=1.51->pybaseball) (2.21)
# Downloading pybaseball-2.2.7-py3-none-any.whl (426 kB)
# Downloading PyGithub-2.5.0-py3-none-any.whl (375 kB)
# Downloading PyNaCl-1.5.0-cp36-abi3-macosx_10_10_universal2.whl (349 kB)
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Installing collected packages: Deprecated, pynacl, pygithub, pybaseball
# Successfully installed Deprecated-1.2.14 pybaseball-2.2.7 pygithub-2.5.0 pynacl-1.5.0

# %%
import os 
import pandas as pd
import numpy as np
from pybaseball import batting_stats

# %%
START = 2002
END = 2022

# %%
batting = batting_stats(START, END, qual=200) # qual is how many min plate appearances we want a batter to have

# %%
batting.to_csv("/Users/dhruth/Desktop/WAR_prediction_project/batting.csv")

# %%
# remove players that we only have 1 season of data for
batting = batting.groupby("IDfg", group_keys=False).filter(lambda x: x.shape[0] > 1)
                                                      # the filter keeps groups where we have at least 2 seasons of data for the player

# %%
batting
# Out:
#        IDfg  Season          Name Team  Age    G   AB   PA    H   1B  ...  \
# 0      1109    2002   Barry Bonds  SFG   37  143  403  612  149   70  ...
# 1      1109    2004   Barry Bonds  SFG   39  147  373  617  135   60  ...
# 8     15640    2022   Aaron Judge  NYY   30  157  570  696  177   87  ...
# 2      1109    2003   Barry Bonds  SFG   38  130  390  550  133   65  ...
# 15    13611    2018  Mookie Betts  BOS   25  136  520  614  180   96  ...
# ...     ...     ...           ...  ...  ...  ...  ...  ...  ...  ...  ...
# 7042   9272    2018   Chris Davis  BAL   32  128  470  522   79   51  ...
# 6535     45    2012   Rod Barajas  PIT   36  104  321  361   66   44  ...
# 6673    319    2011     Adam Dunn  CHW   31  122  415  496   66   39  ...
# 6988    620    2002   Neifi Perez  KCR   29  145  554  585  131  104  ...
# 978    2113    2008   Ryan Doumit  PIT   27  116  431  465  137   88  ...
#
#       maxEV  HardHit  HardHit%  Events  CStr%   CSW%  xBA  xSLG  xwOBA  L-WAR
# 0       NaN      NaN       NaN       0  0.127  0.191  NaN   NaN    NaN   12.7
# 1       NaN      NaN       NaN       0  0.124  0.164  NaN   NaN    NaN   11.9
# 8     118.4    246.0     0.609     404  0.169  0.287  NaN   NaN    NaN   11.4
# 2       NaN      NaN       NaN       0  0.135  0.223  NaN   NaN    NaN   10.2
# 15    110.6    217.0     0.500     434  0.220  0.270  NaN   NaN    NaN   10.4
# ...     ...      ...       ...     ...    ...    ...  ...   ...    ...    ...
# 7042  111.8    113.0     0.401     282  0.174  0.316  NaN   NaN    NaN   -2.6
# 6535    NaN      0.0       NaN       0  0.147  0.258  NaN   NaN    NaN   -2.6
# 6673    NaN      0.0       NaN       0  0.169  0.295  NaN   NaN    NaN   -2.9
# 6988    NaN      NaN       NaN       0  0.130  0.187  NaN   NaN    NaN   -2.9
# 978     NaN      0.0       NaN       0  0.144  0.231  NaN   NaN    NaN   -3.1
#
# [6754 rows x 320 columns]

# %% [markdown]
# ## Creating a target

# %%
def next_season(player):
    player = player.sort_values("Season")
    player["Next_WAR"] = player["WAR"].shift(-1)
    return player

batting = batting.groupby("IDfg", group_keys=False).apply(next_season)
# Out:
# /var/folders/hc/ft3hypk91rs7_8vw457rn2000000gn/T/ipykernel_94421/1658847979.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   batting = batting.groupby("IDfg", group_keys=False).apply(next_season)

# %%
# let's explore what the shift is doing
batting[["Name", "Season", "WAR", "Next_WAR"]]
# Out:
#                  Name  Season  WAR  Next_WAR
# 5562  Alfredo Amezaga    2006  1.1       2.0
# 5006  Alfredo Amezaga    2007  2.0       1.2
# 5252  Alfredo Amezaga    2008  1.2       NaN
# 1169  Garret Anderson    2002  3.7       5.1
# 864   Garret Anderson    2003  5.1       0.8
# ...               ...     ...  ...       ...
# 6002      Owen Miller    2022  0.7       NaN
# 4881    Andrew Vaughn    2021 -0.2      -0.5
# 3377    Andrew Vaughn    2022 -0.5       NaN
# 6620     Ha-seong Kim    2021  0.4       3.6
# 4396     Ha-seong Kim    2022  3.6       NaN
#
# [6754 rows x 4 columns]

# %% [markdown]
# ## Cleaning the data

# %%
# getting rid of null values
null_count = batting.isnull().sum()

# %%
null_count
# Out:
# IDfg           0
# Season         0
# Name           0
# Team           0
# Age            0
#             ...
# xBA         6754
# xSLG        6754
# xwOBA       6754
# L-WAR          0
# Next_WAR    1179
# Length: 321, dtype: int64

# %%
# we are only selecting the columns with null count 0
complete_cols = list(batting.columns[null_count == 0])

# %%
complete_cols
# Out:
# ['IDfg',
#  'Season',
#  'Name',
#  'Team',
#  'Age',
#  'G',
#  'AB',
#  'PA',
#  'H',
#  '1B',
#  '2B',
#  '3B',
#  'HR',
#  'R',
#  'RBI',
#  'BB',
#  'IBB',
#  'SO',
#  'HBP',
#  'SF',
#  'SH',
#  'GDP',
#  'SB',
#  'CS',
#  'AVG',
#  'GB',
#  'FB',
#  'LD',
#  'IFFB',
#  'Pitches',
#  'Balls',
#  'Strikes',
#  'IFH',
#  'BU',
#  'BUH',
#  'BB%',
#  'K%',
#  'BB/K',
#  'OBP',
#  'SLG',
#  'OPS',
#  'ISO',
#  'BABIP',
#  'GB/FB',
#  'LD%',
#  'GB%',
#  'FB%',
#  'IFFB%',
#  'HR/FB',
#  'IFH%',
#  'BUH%',
#  'wOBA',
#  'wRAA',
#  'wRC',
#  'Bat',
#  'Rep',
#  'Pos',
#  'RAR',
#  'WAR',
#  'Dol',
#  'Spd',
#  'wRC+',
#  'WPA',
#  '-WPA',
#  '+WPA',
#  'RE24',
#  'REW',
#  'pLI',
#  'PH',
#  'WPA/LI',
#  'Clutch',
#  'FB% (Pitch)',
#  'FBv',
#  'SL%',
#  'SLv',
#  'CB%',
#  'CBv',
#  'CH%',
#  'CHv',
#  'wFB',
#  'wSL',
#  'wCB',
#  'wCH',
#  'wFB/C',
#  'wSL/C',
#  'wCB/C',
#  'wCH/C',
#  'O-Swing%',
#  'Z-Swing%',
#  'Swing%',
#  'O-Contact%',
#  'Z-Contact%',
#  'Contact%',
#  'Zone%',
#  'F-Strike%',
#  'SwStr%',
#  'BsR',
#  'Def',
#  'wSB',
#  'UBR',
#  'Age Rng',
#  'Off',
#  'Lg',
#  'wGDP',
#  'Pull%',
#  'Cent%',
#  'Oppo%',
#  'Soft%',
#  'Med%',
#  'Hard%',
#  'TTO%',
#  'AVG+',
#  'BB%+',
#  'K%+',
#  'OBP+',
#  'SLG+',
#  'ISO+',
#  'BABIP+',
#  'LD+%',
#  'GB%+',
#  'FB%+',
#  'HR/FB%+',
#  'Pull%+',
#  'Cent%+',
#  'Oppo%+',
#  'Soft%+',
#  'Med%+',
#  'Hard%+',
#  'Events',
#  'CStr%',
#  'CSW%',
#  'L-WAR']

# %%
# here we are taking our abtting df and selecting all of the complete columns in the df PLUS our Next_WAR
batting = batting[complete_cols + ["Next_WAR"]].copy()

# %%
batting
# Out:
#        IDfg  Season             Name Team  Age    G   AB   PA    H   1B  ...  \
# 5562      1    2006  Alfredo Amezaga  FLA   28  132  334  378   87   72  ...
# 5006      1    2007  Alfredo Amezaga  FLA   29  133  400  448  105   80  ...
# 5252      1    2008  Alfredo Amezaga  FLA   30  125  311  337   82   61  ...
# 1169      2    2002  Garret Anderson  ANA   30  158  638  678  195  107  ...
# 864       2    2003  Garret Anderson  ANA   31  159  638  673  201  119  ...
# ...     ...     ...              ...  ...  ...  ...  ...  ...  ...  ...  ...
# 6002  24655    2022      Owen Miller  CLE   25  130  424  472  103   70  ...
# 4881  26197    2021    Andrew Vaughn  CHW   23  127  417  469   98   61  ...
# 3377  26197    2022    Andrew Vaughn  CHW   24  134  510  555  138   92  ...
# 6620  27506    2021     Ha-seong Kim  SDP   25  117  267  298   54   32  ...
# 4396  27506    2022     Ha-seong Kim  SDP   26  150  517  582  130   87  ...
#
#       Cent%+  Oppo%+  Soft%+  Med%+  Hard%+  Events  CStr%   CSW%  L-WAR  \
# 5562     107     113     143    109      63       0  0.188  0.256    1.1
# 5006     101     112     109    113      75       0  0.175  0.227    2.0
# 5252     101     101     123    111      64       0  0.178  0.244    1.2
# 1169      91      80      65     97     129       0  0.137  0.232    3.7
# 864      101      80      90     99     109       0  0.164  0.252    5.1
# ...      ...     ...     ...    ...     ...     ...    ...    ...    ...
# 6002     111      97     131    100      83     340  0.188  0.266    0.7
# 4881     104     116      84     99     110     321  0.185  0.285   -0.4
# 3377     106     111      94    100     104     419  0.201  0.291   -0.5
# 6620      99      59     137     96      88     201  0.216  0.303    0.5
# 4396     104      71     117    100      90     424  0.205  0.276    3.7
#
#       Next_WAR
# 5562       2.0
# 5006       1.2
# 5252       NaN
# 1169       5.1
# 864        0.8
# ...        ...
# 6002       NaN
# 4881      -0.5
# 3377       NaN
# 6620       3.6
# 4396       NaN
#
# [6754 rows x 133 columns]

# %%
batting.dtypes
# Out:
# IDfg          int64
# Season        int64
# Name         object
# Team         object
# Age           int64
#              ...
# Events        int64
# CStr%       float64
# CSW%        float64
# L-WAR       float64
# Next_WAR    float64
# Length: 133, dtype: object

# %%
batting.dtypes[batting.dtypes == "object"]
# Out:
# Name       object
# Team       object
# Dol        object
# Age Rng    object
# dtype: object

# %%
batting.Dol
# Out:
# 5562      $5.5
# 5006     $11.2
# 5252      $7.2
# 1169     $14.6
# 864      $22.0
#          ...
# 6002      $5.7
# 4881    ($1.6)
# 3377    ($4.0)
# 6620      $3.0
# 4396     $29.2
# Name: Dol, Length: 6754, dtype: object

# %%
del batting["Dol"]

# %%
batting["Age Rng"]
# Out:
# 5562    28 - 28
# 5006    29 - 29
# 5252    30 - 30
# 1169    30 - 30
# 864     31 - 31
#          ...
# 6002    25 - 25
# 4881    23 - 23
# 3377    24 - 24
# 6620    25 - 25
# 4396    26 - 26
# Name: Age Rng, Length: 6754, dtype: object

# %%
del batting["Age Rng"]

# %%
# creaating a column to convert team names into numbers we can use in our model
batting["team_code"] = batting["Team"].astype("category").cat.codes

# %%
batting_full = batting.copy()
batting = batting.dropna().copy()

# %% [markdown]
# ## Useful feature selection

# %%
# let's run a feature selector that can pick a subset of features
# this helps a model optimize its accuracy and reduces overfitting or multicolinearity
from sklearn.linear_model import Ridge
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.model_selection import TimeSeriesSplit

# higher alpha reduces overfitting as it penalizes the rr coefficients
# lower is closer to a pure regular linear regeression
rr = Ridge(alpha = 1)

# splits our data up into 3 parts and make predictions for those parts
split = TimeSeriesSplit(n_splits = 3)

# a forward direction means it's going to start at 0 features and keep going until it finds the best one,
# then repeat the process until it has 20
sfs = SequentialFeatureSelector(rr, n_features_to_select = 20, direction = "forward", cv = split, n_jobs = 4)

# %%
removed_columns = ["Next_WAR", "Name", "Team", "IDfg", "Season"]

# this is saying take all the columns in batting, then pick all of the columns that are NOT in the list of our removed columns 
selected_columns = batting.columns[~batting.columns.isin(removed_columns)]

# %%
# let's scale our data to get a mean of 0 and a s.d of 1 in order for the model to work effectively 
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
batting.loc[:,selected_columns] = scaler.fit_transform(batting[selected_columns])
# Out:
# /var/folders/hc/ft3hypk91rs7_8vw457rn2000000gn/T/ipykernel_94421/1684436960.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.35294118 0.35294118 0.02941176 ... 0.26470588 0.20588235 0.76470588]' has dtype incompatible with int8, please explicitly cast to a compatible dtype first.
#   batting.loc[:,selected_columns] = scaler.fit_transform(batting[selected_columns])
# /var/folders/hc/ft3hypk91rs7_8vw457rn2000000gn/T/ipykernel_94421/1684436960.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.         0.05555556 0.         ... 0.         0.         0.        ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:,selected_columns] = scaler.fit_transform(batting[selected_columns])

# %%
batting.describe()
# Out:
#                IDfg       Season          Age            G           AB  \
# count   5575.000000  5575.000000  5575.000000  5575.000000  5575.000000
# mean    5366.785830  2011.163229     0.360600     0.652755     0.478666
# std     5133.255295     5.612014     0.147476     0.255929     0.242481
# min        1.000000  2002.000000     0.000000     0.000000     0.000000
# 25%     1131.500000  2006.000000     0.269231     0.478632     0.275180
# 50%     3531.000000  2011.000000     0.346154     0.709402     0.505396
# 75%     9015.000000  2016.000000     0.461538     0.871795     0.688849
# max    27506.000000  2021.000000     1.000000     1.000000     1.000000
#
#                 PA            H           1B           2B           3B  ...  \
# count  5575.000000  5575.000000  5575.000000  5575.000000  5575.000000  ...
# mean      0.480943     0.365973     0.290481     0.399279     0.103459  ...
# std       0.262290     0.182585     0.138786     0.171732     0.105891  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       0.257785     0.211207     0.179245     0.258621     0.043478  ...
# 50%       0.508651     0.370690     0.283019     0.379310     0.086957  ...
# 75%       0.710208     0.508621     0.391509     0.517241     0.130435  ...
# max       1.000000     1.000000     1.000000     1.000000     1.000000  ...
#
#             Events        CStr%         CSW%        L-WAR     Next_WAR  \
# count  5575.000000  5575.000000  5575.000000  5575.000000  5575.000000
# mean      0.172991     0.498932     0.545898     0.322040     1.793130
# std       0.273858     0.137180     0.120701     0.122153     1.981035
# min       0.000000     0.000000     0.000000     0.000000    -3.100000
# 25%       0.000000     0.408511     0.466960     0.234177     0.350000
# 50%       0.000000     0.493617     0.546256     0.303797     1.500000
# 75%       0.346411     0.591489     0.625551     0.392405     2.900000
# max       1.000000     1.000000     1.000000     1.000000    11.900000
#
#          team_code  player_season     war_corr     war_diff   war_season
# count  5575.000000    5575.000000  5575.000000  5575.000000  5575.000000
# mean      0.474128       0.171729     0.519349     0.040936     0.324167
# std       0.305105       0.161822     0.301989     0.023514     0.121909
# min       0.000000       0.000000     0.000000     0.000000     0.000000
# 25%       0.205882       0.055556     0.320207     0.031250     0.236615
# 50%       0.470588       0.111111     0.500000     0.038462     0.304873
# 75%       0.735294       0.277778     0.747458     0.045490     0.392408
# max       1.000000       1.000000     1.000000     1.000000     1.000000
#
# [8 rows x 134 columns]

# %%
sfs.fit(batting[selected_columns], batting["Next_WAR"])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=Ridge(alpha=1), n_features_to_select=20,
#                           n_jobs=4)

# %%
# finding the features that were selected
predictors = list(selected_columns[sfs.get_support()])
predictors
# Out:
# ['Age',
#  'IBB',
#  'SO',
#  'SB',
#  'BU',
#  'BABIP',
#  'Spd',
#  'PH',
#  'CB%',
#  'CH%',
#  'Swing%',
#  'wGDP',
#  'ISO+',
#  'LD+%',
#  'Oppo%+',
#  'Soft%+',
#  'Hard%+',
#  'war_corr',
#  'war_diff',
#  'war_season']

# %% [markdown]
# ## Making predictions

# %%
# geenrates our predictions for us
def backtest(data, model, predictors, start = 5, step = 1):
    all_predictions = [] # each element in this list is going to be the predictions for a single season
    years = sorted(batting["Season"].unique())

    for i in range(start, len(years), step): # each time through this loop, we are going to use historizal data to predict a single season
        current_year = years[i]
        
        train = data[data["Season"] < current_year]
        test = data[data["Season"] == current_year]

        model.fit(train[predictors], train["Next_WAR"])
        
        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index=test.index)
        combined = pd.concat([test["Next_WAR"], preds], axis=1)
        combined.columns = ["actual", "prediction"]
        
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(batting, rr, predictors)

# %%
predictions
# Out:
#       actual  prediction
# 5006     1.2    1.317902
# 1925     1.4    0.912777
# 3102    -0.1    0.688263
# 5797     0.6    1.080132
# 1109     4.8    2.447246
# ...      ...         ...
# 1914     2.2    2.578483
# 5875     0.8    2.040255
# 7032     0.7    1.531220
# 4881    -0.5    1.663971
# 6620     3.6    1.098457
#
# [4127 rows x 2 columns]

# %%
# hard to tell if the algorithm is good, so let's use a summary statistic to create an error metric
from sklearn.metrics import mean_squared_error # this gives us a single number that tells us how high the error is in our model

mean_squared_error(predictions["actual"], predictions["prediction"])
# Out:
# 2.6892660150410927

# %%
batting["Next_WAR"].describe()
# Out:
# count    5575.000000
# mean        1.793130
# std         1.981035
# min        -3.100000
# 25%         0.350000
# 50%         1.500000
# 75%         2.900000
# max        11.900000
# Name: Next_WAR, dtype: float64

# %%
# we like the sqrt of MSE to be lower than the s.d, indicates that the model is doing something better than randomly guessing
2.7363675228708013 ** 0.5
# Out:
# 1.6541969419844789

# %% [markdown]
# ## Let's improve prediction and accuracy

# %%
ga = batting[batting["IDfg"] == 2].copy()

# %%
ga["player_season"] = range(0, ga.shape[0]) # .shape[0] returns number of rows in the array/df

# %%
ga[["player_season", "WAR"]].expanding().corr() # expanding creates different groups of the df
# Out:
#                     player_season       WAR
# 1169 player_season            NaN       NaN
#      WAR                      NaN       NaN
# 864  player_season       1.000000  1.000000
#      WAR                 1.000000  1.000000
# 2569 player_season       1.000000 -0.661143
#      WAR                -0.661143  1.000000
# 4187 player_season       1.000000 -0.836562
#      WAR                -0.836562  1.000000
# 3964 player_season       1.000000 -0.836312
#      WAR                -0.836312  1.000000
# 1925 player_season       1.000000 -0.692192
#      WAR                -0.692192  1.000000
# 3346 player_season       1.000000 -0.595013
#      WAR                -0.595013  1.000000

# %%
list(ga[["player_season", "WAR"]].expanding().corr().loc[(slice(None), "player_season"), "WAR"])
# Out:
# [nan,
#  1.0,
#  -0.6611430912519526,
#  -0.8365619976685158,
#  -0.8363121929961227,
#  -0.6921918007562199,
#  -0.5950132649769159]

# %%
# giving the algorithm some information on how the player did previously can help it make better predictions

def player_history(df):
    df = df.sort_values("Season")

    df["player_season"] = range(0, df.shape[0]) # indicates which season it is for the player
    df["war_corr"] = list(df[["player_season", "WAR"]].expanding().corr().loc[(slice(None), "player_season"),"WAR"])
    df["war_corr"].fillna(0, inplace=True)

    df["war_diff"] = df["WAR"] / df["WAR"].shift(1) # difference between current WAR and prev season's WAR
    df["war_diff"].fillna(1, inplace=True)
    df["war_diff"][df["war_diff"] == np.inf] = 1
    
    return df

batting = batting.groupby("IDfg", group_keys=False).apply(player_history)

# %%
def group_averages(df):
    return df["WAR"] / df["WAR"].mean()

# %%
batting["war_season"] = batting.groupby("Season", group_keys = False).apply(group_averages)
# Out:
# /var/folders/hc/ft3hypk91rs7_8vw457rn2000000gn/T/ipykernel_94421/1991322583.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   batting["war_season"] = batting.groupby("Season", group_keys = False).apply(group_averages)

# %%
new_predictors = predictors + ["player_season", "war_corr", "war_season", "war_diff"]

# %%
predictions = backtest(batting, rr, new_predictors)

# %%
mean_squared_error(predictions["actual"], predictions["prediction"])
# Out:
# 2.683291500773334

# %%
pd.Series(rr.coef_, index=new_predictors).sort_values()
# Out:
# Age             -2.610547
# BABIP           -1.950268
# Soft%+          -1.244190
# ISO+            -1.170234
# BU              -1.023677
# PH              -0.785004
# SO              -0.672380
# wGDP            -0.341390
# CB%             -0.325741
# Swing%          -0.304232
# LD+%            -0.277597
# CH%             -0.223799
# war_diff        -0.142285
# war_diff        -0.142285
# war_corr        -0.067776
# war_corr        -0.067776
# player_season    0.003110
# Oppo%+           0.707870
# Spd              0.788975
# SB               1.083423
# war_season       1.291036
# war_season       1.291036
# IBB              2.088754
# Hard%+           2.372181
# dtype: float64

# %%
diff = predictions["actual"] - predictions["prediction"]

# %%
merged = predictions.merge(batting, left_index=True, right_index=True)

# %%
merged["diff"] = (predictions["actual"] - predictions["prediction"]).abs()

# %%
merged[["IDfg", "Season", "Name", "WAR", "Next_WAR", "diff"]].sort_values(["diff"]).head(20)
# Out:
#        IDfg  Season              Name       WAR  Next_WAR      diff
# 3352    746    2009   A.J. Pierzynski  0.341772       1.4  0.000539
# 1631   2396    2014    Carlos Santana  0.341772       2.1  0.001419
# 245   16376    2020  Michael Conforto  0.310127       1.5  0.001743
# 340   14162    2017     Carlos Correa  0.506329       3.7  0.001765
# 5459   6012    2019    Didi Gregorius  0.164557       0.7  0.001843
# 6814   4062    2018     Dexter Fowler  0.094937       0.5  0.001928
# 264   20043    2021   Luis Robert Jr.  0.417722       2.2  0.002284
# 2349  12564    2021      Trevor Story  0.335443       2.5  0.002661
# 1288  11368    2019   Yasmani Grandal  0.556962       3.6  0.003083
# 5715  13768    2016  Travis Jankowski  0.259494       1.4  0.003731
# 3410   3473    2020     Anthony Rizzo  0.259494       2.2  0.004252
# 4590   3856    2009    Jeff Keppinger  0.208861       1.4  0.004262
# 2055   9218    2019  Paul Goldschmidt  0.386076       2.1  0.005611
# 2581  11476    2016    Odubel Herrera  0.436709       2.7  0.005622
# 2082   5887    2013         John Jaso  0.234177       0.6  0.005694
# 1156  10339    2013   Scooter Gennett  0.322785       1.7  0.005837
# 2713  20126    2021     Dylan Carlson  0.348101       1.9  0.006054
# 2759   3353    2012        Matt Joyce  0.316456       2.0  0.006458
# 776   13359    2016      Tyler Naquin  0.316456       1.4  0.006912
# 6710  13613    2016       Ketel Marte  0.215190       1.1  0.007686
